# %% [markdown]
# <a href="https://colab.research.google.com/github/Rani19-droid/DSA-6th-13th_june-2301220100131/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = list(range(0,7))
print(a)
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
a = list(range(0,8,2))
print(a)
# Out:
# [0, 2, 4, 6]

# %%
list_1= [0,1,2,3]
list_2=[0,2,4,6]
lst=[]
for i in range(0,len(list_1)):
 x = list_1[i]*list_2[i]
 lst.append(x)
 print("the product is ",lst)
# Out:
# the product is  [0]
# the product is  [0, 2]
# the product is  [0, 2, 8]
# the product is  [0, 2, 8, 18]

# %%
z=[0,1,2,3]
print(z*2)
# Out:
# [0, 1, 2, 3, 0, 1, 2, 3]

# %%
x=np.array([2.1,3.4,5.1],dtype='int')
print(x)
# Out:
# [2 3 5]

# %%
a=np.array([1,2,3,4,5])
print(a,type(a))
# Out:
# [1 2 3 4 5] <class 'numpy.ndarray'>

# %%
a= np.array([1,2,3,4,5,'abc',3.1])
print(a,type(a), a.shape)
# Out:
# ['1' '2' '3' '4' '5' 'abc' '3.1'] <class 'numpy.ndarray'> (7,)

# %%
a1=np.array([[1,2,3],[1,2,3]])
print(a1,a1.shape)
# Out:
# [[1 2 3]
#  [1 2 3]] (2, 3)
